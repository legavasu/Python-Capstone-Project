# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ArchanaInsights/Datasets/main/marketing_campaign.csv')
df
# Out:
#        Campaign_ID              Company Campaign_Type Target_Audience  \
# 0                1             TechCorp         Email     Women 25-34
# 1                2  Innovate Industries    Influencer     Women 35-44
# 2                3       NexGen Systems  Social Media     Women 25-34
# 3                4  Innovate Industries         Email     Women 25-34
# 4                5  Data Tech Solutions    Influencer       Men 25-34
# ...            ...                  ...           ...             ...
# 22024        22025  Data Tech Solutions        Search       Men 18-24
# 22025        22026  Data Tech Solutions  Social Media       Men 18-24
# 22026        22027             TechCorp    Influencer     Women 25-34
# 22027        22028  Data Tech Solutions        Search       Men 18-24
# 22028        22029       NexGen Systems        Search       Men 18-24
#
#       Duration Channel_Used  Conversion_Rate  Acquisition_Cost     ROI  \
# ...

# %% [markdown]
# 2) Descriptive Analysis
#
# Basic Structure:➢ Print the first few rows of the dataset to get an overview of the data.
# ➢ Obtain the number of rows and columns in the dataset.
# ➢ Get a concise summary of the dataset, including the data types and non-null values.
# ➢ Generate descriptive statistics for numerical columns.

# %%
df.head()
# Out:
#    Campaign_ID              Company Campaign_Type Target_Audience Duration  \
# 0            1             TechCorp         Email     Women 25-34  30 days
# 1            2  Innovate Industries    Influencer     Women 35-44  45 days
# 2            3       NexGen Systems  Social Media     Women 25-34  45 days
# 3            4  Innovate Industries         Email     Women 25-34  45 days
# 4            5  Data Tech Solutions    Influencer       Men 25-34  30 days
#
#   Channel_Used  Conversion_Rate  Acquisition_Cost     ROI          Location  \
# 0     Facebook         5.294194              9344   62.94           Houston
# 1   Google Ads         3.326375              8783   10.67  Washington, D.C.
# 2    Instagram         4.056375              9111   73.20             Miami
# 3    Instagram         4.496375              7420   60.92           Seattle
# 4   Google Ads         4.405930              2146  138.82           Chicago
#
# ...

# %%
print(df.shape,'\n\n')
print(df.info())
# Out:
# (22029, 16)
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22029 entries, 0 to 22028
# Data columns (total 16 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Campaign_ID       22029 non-null  int64
#  1   Company           22029 non-null  object
#  2   Campaign_Type     22029 non-null  object
#  3   Target_Audience   22029 non-null  object
#  4   Duration          22029 non-null  object
#  5   Channel_Used      22029 non-null  object
#  6   Conversion_Rate   22029 non-null  float64
#  7   Acquisition_Cost  22029 non-null  int64
#  8   ROI               22029 non-null  float64
#  9   Location          22029 non-null  object
#  10  Language          22029 non-null  object
#  11  Clicks            22029 non-null  int64
#  12  Impressions       22029 non-null  int64
#  13  Engagement_Score  22029 non-null  int64
#  14  Customer_Segment  22029 non-null  object
#  15  Date              22029 non-null  object
# ...

# %%
df.describe()
# Out:
#         Campaign_ID  Conversion_Rate  Acquisition_Cost           ROI  \
# count  22029.000000     22029.000000      22029.000000  22029.000000
# mean   11015.000000         4.757232       5522.740842    182.863648
# std     6359.368876         0.960393       2597.666260    301.619721
# min        1.000000         2.015723       1000.000000    -98.300000
# 25%     5508.000000         4.130705       3286.000000     -4.080000
# 50%    11015.000000         4.761527       5525.000000     93.650000
# 75%    16522.000000         5.429335       7766.000000    247.310000
# max    22029.000000         7.469907       9999.000000   3109.790000
#
#              Clicks   Impressions  Engagement_Score
# count  22029.000000  22029.000000      22029.000000
# mean    2223.807572  50610.402787          6.582323
# std     1394.166380  28542.979123          1.458804
# min       30.000000   1001.000000          4.000000
# 25%     1067.000000  25804.000000          5.000000
# ...

# %% [markdown]
# Data Exploration:
# ➢ Print the number of unique Campaign_ID values in the dataset.
# ➢ List the unique values of the Location and Customer_Segment columns.
# ➢ Count the occurrences of each category in the Campaign_Type and
# Channel_Used and columns.

# %%
df['Campaign_ID'].nunique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-802036a3bd96> in <cell line: 1>()
# ----> 1 df['Campaign_ID'].nunique()
#
# NameError: name 'df' is not defined

# %%
pd.concat([df['Location'] ,df['Customer_Segment']]).unique()
# Out:
# array(['Houston', 'Washington, D.C.', 'Miami', 'Seattle', 'Chicago',
#        'Los Angeles', 'Atlanta', 'Dallas', 'New York', 'San Francisco',
#        'Tech Enthusiasts', 'Foodies', 'Fashionistas',
#        'Outdoor Adventurers', 'Health & Wellness'], dtype=object)

# %%
df['Campaign_Type'].value_counts()
# Out:
# Campaign_Type
# Display         4450
# Search          4441
# Social Media    4412
# Email           4388
# Influencer      4338
# Name: count, dtype: int64

# %%
df['Channel_Used'].value_counts()
# Out:
# Channel_Used
# Facebook      3742
# Google Ads    3694
# Website       3688
# Instagram     3649
# YouTube       3632
# Email         3624
# Name: count, dtype: int64

# %% [markdown]
# 3) Exploratory Data Analysis (EDA) and Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Campaign Performance: ➢ Plot a scatter plot to visualize the relationship between Acquisition_Cost and ROI. ➢ Create a bar chart to visualize the average Conversion_Rate for different Channel_Used, categorized by Campaign_Type. ➢ Visualize the distribution of Engagement_Score across different Campaign_Type using a box plot. ➢ Analyze the average ROI by Company using a bar chart to compare the profitability of campaigns conducted by different companies. ➢ Examine the correlation between Engagement_Score and Conversion_Rate using a heatmap.

# %%
plt.figure(figsize=(12,6))
plt.title('Acquisition_Cost vs ROI',fontsize = '10',fontweight ='bold')
sns.scatterplot(x='Acquisition_Cost',y='ROI',data = df)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x='Channel_Used',y='Conversion_Rate',data = df,hue='Campaign_Type',estimator='mean',palette=['b','g','y','pink','r'])
plt.title("Channel Used")
plt.ylim(0,6)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.title("Distribution across Campaign type",fontsize = 10,fontweight ='bold')
plt.xticks(rotation=45)
sns.boxplot(x='Campaign_Type',y='Engagement_Score',data = df,hue='Campaign_Type')
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.title("Comparison of average ROI by Company and Campaigns")
sns.barplot(x='Company',y='ROI',estimator='mean',data=df,hue='Campaign_Type')
plt.show()

# %%
Correlation = df[['Engagement_Score','Conversion_Rate']].corr()
Correlation
# Out:
#                   Engagement_Score  Conversion_Rate
# Engagement_Score          1.000000         0.010546
# Conversion_Rate           0.010546         1.000000

# %%
sns.heatmap(Correlation,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# Customer Segmentation: ➢ Create a count plot to visualize the distribution of Target_Audience. ➢ Identify which Customer_Segment has the highest Conversion_Rate for each Language using a bar chart. ➢ Visualize the distribution of Acquisition_Cost across each Customer_Segment, categorized by Channel_Used, using a box plot. ➢ Analyze average Conversion_Rate by Language using a bar chart to compare the effectiveness of campaigns conducted in different languages.

# %%
plt.figure(figsize=(12,6))
ax=sns.countplot(x='Target_Audience',data =df,width=0.5,color='blue')
ax.bar_label(ax.containers[0])
plt.title("Target Count",fontsize=10,fontweight='bold')
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.ylim(0,9)
plt.title("Customer Segment with Highest Conversion Rate for Each Language",fontweight='bold')
ax = sns.barplot(x='Customer_Segment',y='Conversion_Rate',hue='Language',data=df,estimator='max',width=0.9)
for container in ax.containers:
    ax.bar_label(container,fmt='%.2f')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.title("Distribution of Acquisition Cost across Customer Segments by Channel Used",fontweight='bold')
sns.boxplot(x='Customer_Segment',y='Acquisition_Cost',hue='Channel_Used',data = df)
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.title("Average Conversion Rate by Language and Campaigns",fontweight='bold')
ax=sns.barplot(x='Language',y='Conversion_Rate',data =df,hue='Campaign_Type',width = 0.8)
for container in ax.containers:
    ax.bar_label(container,fmt='%.2f', padding=4)
plt.show()

# %% [markdown]
# Channel Effectiveness:➢ Compare the Engagement_Score for different Channels_Used, segmented by
# Campaign_Type, using a bar chart.
# ➢ Show the distribution of total ROI across different Channels_Used using a pie
# chart.
# ➢ Plot a scatter plot to show the relationship between Clicks and Impressions
# for each Channel_Used.

# %%
plt.figure(figsize=(12,6))
plt.title("Comparison of Engagement Score for different Channels Used and Campaign Type",fontweight='bold')
sns.barplot(x='Channel_Used',y='Engagement_Score',hue='Campaign_Type',data =df,palette='Set2')
plt.show()

# %%
pie = df.groupby('Channel_Used')['ROI'].sum()
plt.title("Distribution of total ROI across Channels Used")
plt.pie(pie,labels=(pie.index),autopct='%1.2f%%',shadow=True)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.title("Relationship between Clicks and Impressions by Channel Used",fontweight='bold')
sns.scatterplot(x='Clicks',y='Impressions',hue='Channel_Used',data =df)
plt.show()

# %% [markdown]
# Time-Based Analysis: ➢ Plot the distribution of Duration using a histogram. ➢ Analyze how the overall Conversion_Rate has changed over Date for each Company using a line chart. ➢ Examine the trend of Engagement_Score over Date with a lineline

# %%
plt.figure(figsize=(12,6))
plt.title("Distribution of Duration")
sns.histplot(x="Duration",data =df,kde=True,color='Green')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.title("Analysing overall Conversion Rate of Company by Date",fontweight='bold')
sns.lineplot(x='Date',y='Conversion_Rate',data =df,hue='Company',style='Company',marker='o',errorbar=None)
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.title("Trend of Engagement_Score over Date")
sns.lineplot(x='Date',y='Engagement_Score',data =df,errorbar=None,marker='o',markeredgecolor='r',linestyle='--')
plt.show()

# %% [markdown]
# Geographic Analysis:➢ Determine which location has the highest Acquisition_Cost using a bar chart.
# ➢ Visualize the Conversion_Rate by different Location, categorized by
# Target_Audience, using a bar chart.
# ➢ Illustrate the proportion of ROI by Location using a pie chart.

# %%
plt.figure(figsize=(15,6))
plt.title("Locations cost",fontweight='bold')
plt.xticks(rotation=45)
ax =sns.barplot(x='Location',y='Acquisition_Cost',hue='Location',data = df,errorbar=None)
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.title("Visualizing the Conversion_Rate by Location and Target Audience",fontweight='bold')
plt.xticks(rotation=45)
sns.barplot(x='Location',y='Conversion_Rate',hue='Target_Audience',data =df,palette='Set3',width=0.8)
plt.show()

# %%
proportion = df.groupby('Location')['ROI'].sum()
proportion
# Out:
# Location
# Atlanta             384348.19
# Chicago             432257.42
# Dallas              422771.06
# Houston             427727.23
# Los Angeles         416718.64
# Miami               400086.36
# New York            380121.73
# San Francisco       374367.54
# Seattle             390251.85
# Washington, D.C.    399653.29
# Name: ROI, dtype: float64

# %%
plt.figure(figsize=(15,6))
plt.title("Proportion of ROI by Location",fontweight='bold')
plt.pie(proportion,labels=proportion.index,autopct='%1.2f%%',shadow=True,startangle=90)
plt.show()
